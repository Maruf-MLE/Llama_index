# %%
from llama_index.core import Settings
from dotenv import load_dotenv
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
Settings.embed_model=embed_model=HuggingFaceEmbedding(model_name='Qwen/Qwen3-Embedding-0.6B')
load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from llama_index.core import Settings
#       2 from dotenv import load_dotenv
# ----> 3 from llama_index.embeddings.huggingface import HuggingFaceEmbedding
#       4 Settings.embed_model=embed_model=HuggingFaceEmbedding(model_name='Qwen/Qwen3-Embedding-0.6B')
#       5 load_dotenv()
#
# ModuleNotFoundError: No module named 'llama_index.embeddings.huggingface'

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core.node_parser import SentenceSplitter

documents=SimpleDirectoryReader(
    input_dir='Data'
).load_data()

spliter=SentenceSplitter(
    chunk_size=100,
    chunk_overlap=20
)

# %%
from llama_index.core import StorageContext, VectorStoreIndex
from llama_index.vector_stores.chroma import ChromaVectorStore
import chromadb

# %%
from llama_index.core.settings import Settings

# %%
chroma_client= chromadb.Client()
collection=chroma_client.get_or_create_collection(
    name='Chroma_collection'
)

vector_store=ChromaVectorStore(
    chroma_collection=collection
)

storage_context=StorageContext.from_defaults(
    vector_store=vector_store
)

index = VectorStoreIndex.from_documents(
    documents=documents,
    storage_context=storage_context,
    transformations=[spliter]
)

print(chroma_client.list_collections())
list=chroma_client.get_collection('Chroma_collection')
print(list.count())
print(list.get(limit=5))
# Out:
# [Collection(name=Chroma_collection)]
# 21
# ...

# %%
collection3=chroma_client.get_collection('Chroma_collection')

# collectionf=collection3.get()
# collectionf['ids']
# collection3.get(ids=['43cd5732-af79-47b0-bd13-3f90dba98ac9'])
collectionf
# collection3.delete(ids='43cd5732-af79-47b0-bd13-3f90dba98ac9')
collection3.delete(
    where={'documents':'LlamaIndex helps build Retrieval-Augmented Generation (RAG) systems'}
)
# collection3.get(['43cd5732-af79-47b0-bd13-3f90dba98ac9'])
# collection3.get()
collection3.query(
    query_texts='what is rag',
    n_results=3
)
# Out:
# ---------------------------------------------------------------------------
# ConnectTimeout                            Traceback (most recent call last)
# File d:\Coding\venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File d:\Coding\venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File d:\Coding\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# ...

# %%
print(type(index))

print(index)
# Out:
# <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'>
# ...

# %%
from llama_index.vector_stores.faiss import FaissVectorStore
from llama_index.core import StorageContext
import faiss

# dimension = embedding size
faiss_index = faiss.IndexFlatL2(384)  # HF MiniLM = 384

vector_store = FaissVectorStore(faiss_index=faiss_index)

storage_context = StorageContext.from_defaults(
    vector_store=vector_store
)

index = VectorStoreIndex.from_documents(
    documents,
    transformations=[splitter],
    storage_context=storage_context
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from llama_index.vector_stores.faiss import FaissVectorStore
#       2 from llama_index.core import StorageContext
#       3 import faiss
#
# ModuleNotFoundError: No module named 'llama_index.vector_stores.faiss'

# %%
from llama_index.vector_stores.pinecone import PineconeVectorStore
from llama_index.core import StorageContext
import pinecone

pinecone.init(
    api_key="ENV থেকে",  # usually env
    environment="us-east1-gcp"
)

index_pc = pinecone.Index("my-index")

vector_store = PineconeVectorStore(
    pinecone_index=index_pc
)

storage_context = StorageContext.from_defaults(
    vector_store=vector_store
)

index = VectorStoreIndex.from_documents(
    documents,
    transformations=[splitter],
    storage_context=storage_context
)
