# %%
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import SimpleDirectoryReader,VectorStoreIndex

documents=SimpleDirectoryReader(
    input_dir='Data'
)
data=documents.load_data()
spliter= SentenceSplitter(
    chunk_size=100,
    chunk_overlap=20
)
index=VectorStoreIndex.from_documents(
    documents=data,
    transformations=[spliter]
)
print(type(index))
print(len(index))
print(index)

# %%
from llama_index.core.node_parser import TokenTextSplitter
token_spliter=TokenTextSplitter(
    chunk_size=100,
    chunk_overlap=20
)

# %%
from llama_index.core.node_parser import MarkdownElementNodeParser
Markdown_spliter=MarkdownElementNodeParser()

# %%
from llama_index.core.node_parser import HTMLNodeParser
html_spliter = HTMLNodeParser()

# %%
from llama_index.core.node_parser import CodeSplitter

code_spliter = CodeSplitter(
    language='python',
    chunk_lines=40,
    chunk_lines_overlap=5
)

# %%
from llama_index.core.node_parser import SemanticSplitterNodeParser
from llama_index.core import Settings

semantic_spliter = SemanticSplitterNodeParser(
    embed_model=Settings.embed_model,
    buffer_size=1,
    breakpoint_percentile_threshold=95
)
